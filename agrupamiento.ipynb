# %%
import pandas as pd
import numpy as np

# %%
df_museo = pd.read_csv('museos-2022 - 01.csv',delimiter=';')

# Tomamos el datafram de Museos

# %%
df_museo.head(3)

# check info
# Out:
#    Unnamed: 0  cod_localidad  id_provincia  id_departamento  \
# 0           0        6588100             6             6588
# 1           1        6077010             6             6077
# 2           2        6035010             6             6035
#
#                             categoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial  Buenos Aires  Avellaneda
#
#                                             nombre  \
# 0   Archivo Y Museo Histórico Gral. Julio De Vedia
# 1           Museo Y Archivo Histórico De Arrecifes
# 2  Museo Histórico-Sacro  Hno. Rogelio Scortegagna
#
#                           domicilio codigo postal numero de telefono  \
# 0                     Libertad 1191      B6500EVL        2317425 279
# 1            Gerardo Risso y España      B2740FMJ        2478452 931
# ...

# %%
df_bibliotecas = pd.read_csv('Bibliotecas Populares-2022 - 01.csv',delimiter=';')

# Tomamos el datafram de bibliotecas populares

# %%
df_bibliotecas.head(3)

# chekc info
# Out:
#    Unnamed: 0  cod_localidad  id_provincia  id_departamento  \
# 0           0       70049060            70            70049
# 1           1        2000010             2             2000
# 2           2        2000010             2             2000
#
#                categoria                        provincia  \
# 0  Bibliotecas Populares                         San Juan
# 1  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
# 2  Bibliotecas Populares  Ciudad Autónoma de Buenos Aires
#
#                 localidad                                       nombre  \
# 0                   Rodeo         Biblioteca Popular Juan P. Garramuno
# 1  Ciudad de Buenos Aires  Biblioteca Popular Helena Larroque de Roffo
# 2  Ciudad de Buenos Aires             Biblioteca Popular 12 de Octubre
#
#               domicilio codigo postal numero de telefono  \
# 0         Santo Domingo          5465             s/ds/d
# 1          Simbrón 3058      C1417EUD         1145010078
# ...

# %%
df_cines = pd.read_csv('Salas de cine-2022 - 01.csv',delimiter=';')

# Tomamos el datafram de Cines

# %%
df_cines.head(3)

# check info
# Out:
#    Unnamed: 0  cod_localidad  id_provincia  id_departamento      categoria  \
# 0           0       10049030            10            10049  Salas de cine
# 1           1       10091150            10            10091  Salas de cine
# 2           2       22140060            22            22140  Salas de cine
#
#    provincia    localidad                       nombre  \
# 0  Catamarca    Catamarca                 Cinemacenter
# 1  Catamarca  Santa María  Centro Cultural San Agustín
# 2      Chaco  Resistencia        Los Cines De La Costa
#
#                        domicilio  codigo postal numero de telefono  \
# 0  Intendente Mamerto Medina 220           4700             s/ds/d
# 1                 San Martin 173           4139         3838421511
# 2             Av. Sarmiento 2600           3500         3794472200
#
#                                       mail  \
# 0                                      s/d
# 1                                      s/d
# ...

# %%
consolidado = pd.concat([df_cines,df_bibliotecas,df_museo])

# Concatemos los dataframe

# %%
consolidado.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  cod_localidad  id_provincia  id_departamento  \
# 0              0       10049030            10            10049
# 1              1       10091150            10            10091
# 2              2       22140060            22            22140
# 3              3       26091020            26            26091
# 4              4       18007010            18            18007
# ...          ...            ...           ...              ...
# 1177        1177       90098040            90            90098
# 1178        1178       90105080            90            90105
# 1179        1179       90105080            90            90105
# 1180        1180       90105070            90            90105
# 1181        1181       90098040            90            90098
#
#                                categoria   provincia          localidad  \
# 0                          Salas de cine   Catamarca          Catamarca
# ...

# %%
consolidado.sample(10)
# Out:
#       Unnamed: 0  cod_localidad  id_provincia  id_departamento  \
# 1117        1117       82063170            82            82063
# 175          175       10049030            10            10049
# 560          560        6441030             6             6441
# 162          162       10105110            10            10105
# 359          359       82084270            82            82084
# 1522        1522       66028050            66            66028
# 1254        1254       74035070            74            74035
# 371          371        2000010             2             2000
# 1062        1062       82021350            82            82021
# 258          258       26007020            26            26007
#
#                                categoria                        provincia  \
# 1117  Espacios de Exhibición Patrimonial                         Santa Fe
# 175   Espacios de Exhibición Patrimonial                        Catamarca
# ...

# %%
conteo_categoria = consolidado.groupby('categoria').count()

# %%
conteo_categoria['Unnamed: 0']
# Out:
# categoria
# Bibliotecas Populares                 2017
# Espacios de Exhibición Patrimonial    1182
# Salas de cine                          329
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# Si 'FUENTE' hace referencia al csv original, tenemos entonces la misma respuesta para conteo por categoria

# %%
conteo_catyprov = consolidado.groupby(['provincia','categoria']).count()

# %%
conteo_catyprov['Unnamed: 0']
# Out:
# provincia                                              categoria
# Buenos Aires                                           Bibliotecas Populares                 543
#                                                        Espacios de Exhibición Patrimonial    152
#                                                        Salas de cine                         106
# Catamarca                                              Bibliotecas Populares                  38
#                                                        Espacios de Exhibición Patrimonial     32
#                                                                                             ...
# Tierra del Fuego                                       Salas de cine                           3
# Tierra del Fuego, Antártida e Islas del Atlántico Sur  Espacios de Exhibición Patrimonial     14
# Tucumán                                                Bibliotecas Populares                  37
# ...

# %% [markdown]
# La última línea nos muestra la respuesta a: Cantidad de registros por Provincia y Categoria
