# %%
import pandas as pd
import os
import shutil

# %%
os.listdir("D:\\")

# Los arhivos descargados en el paso 1, van a:
'D:\Downloads'
# Out:
# 'D:\\Downloads'

# %%
os.listdir("D:\\Downloads")

# Podemos revisar los archivos con os.listdir o OS.walk
# Out:
# ['!!!.pdf',
#  '.picasa.ini',
#  '.picasaoriginals',
#  '0.0_3qJQ.0_3qJQ!attachment!a0_FC-0002-00001992.pdf',
#  '00000000000005716270EQ8NGZV4JDFSYA1JZ74Q.pdf',
#  '00000000000005716316HC8QVZWNVLQJWSRQ10NS.pdf',
#  '0027_202005_MEN.pdf',
#  '0035-00041847 (1).zip',
#  '0035-00041847.zip',
#  '0035-00042245.zip',
#  '0035-00042755.zip',
#  '02723_001001100001039.PDF',
#  '02723_001001100001040.PDF',
#  '03-Function Practice Exercises.ipynb',
#  '04-while Loops.ipynb',
#  '04529408-0035-00041847.pdf',
#  '04529408-0035-00041847_adj (1).pdf',
#  '04529408-0035-00041847_adj.pdf',
#  '04541816-0035-00042245.pdf',
#  '04541816-0035-00042245_adj.pdf',
#  '04561320-0035-00042755.pdf',
#  '04620696-0035-00044000.pdf',
#  '04647800-0035-00044484.pdf',
#  '04761800-0035-00047013.pdf',
#  '04787872-0035-00047647.pdf',
#  '04787872-0035-00047647_adj (1).pdf',
#  '04787872-0035-00047647_adj.pdf',
#  '04812904-0035-00048232.pdf',
#  '04929152-0035-00050690 (1).pdf',
#  '04929152-0035-00050690.pdf',
#  '04929152-0035-00050690_adj.pdf',
#  '04931520-D-0036-00000409.pdf',
#  '04984168-0035-00051889.pdf',
#  '04984168-0035-00051889_adj.pdf',
#  '07-Statements Assessment Test.ipynb',
#  '0918618239.pdf',
#  '11489806722.pdf',
#  '1339 - 2020 -Paclin ( Dosadora para tinta, posicionador e c olocador de tampas, dispersor e tanque)- exportação.pdf',
#  '1339 - 2020 -Paclin ( Dosadora para tinta, posicionador e c olocador de tampas, dispersor e tanque).pdf',
#  '15264.pdf',
#  '15288.pdf',
#  '15289.pdf',
#  '15444.pdf',
#  '1596045393355_PERMISO.pdf',
#  '16404.pdf',
#  '16741570_00254496876_64.pdf',
#  '20200626 fc5509 cli376.pdf',
#  '20200629 fc5514 cli376.pdf',
#  '20200630 fc5527 cliI376.pdf',
#  '20201224_235802.mp4',
#  '2021_11_23_receipt.pdf',
#  '20343166355_011_00002_00000347.pdf',
#  '20348390091_2018_presentacion_1.pdf',
#  '22.8 M MASERA. MORALES (1).xls',
#  '25918077_00408449276_71.pdf',
#  '261588AD83097CD3B22D36AA12281B6F_labels.pdf',
#  '27337281848_011_00001_00000036 (1).pdf',
#  '27337281848_011_00001_00000036.pdf',
#  '27337281848_011_00001_00000037.pdf',
#  '27337281848_011_00001_00000038.pdf',
#  '27337281848_011_00001_00000039.pdf',
#  '27337281848_011_00001_00000040.pdf',
#  '27337281848_011_00001_00000041.pdf',
#  '27337281848_011_00001_00000042.pdf',
#  '27337281848_011_00001_00000043.pdf',
#  '27337281848_011_00001_00000044.pdf',
#  '27337281848_011_00001_00000045.pdf',
#  '27337281848_011_00001_00000046.pdf',
#  '27337281848_011_00001_00000047.pdf',
#  '27337281848_011_00001_00000048.pdf',
#  '27337281848_011_00001_00000049.pdf',
#  '27337281848_011_00001_00000050.pdf',
#  '27337281848_011_00001_00000053.pdf',
#  '27337281848_011_00001_00000054.pdf',
#  '27337281848_011_00001_00000055.pdf',
#  '27337281848_011_00001_00000056.pdf',
#  '27337281848_011_00001_00000057.pdf',
#  '27337281848_011_00001_00000058.pdf',
#  '27337281848_011_00001_00000062.pdf',
#  '27337281848_011_00001_00000066.pdf',
#  '27337281848_011_00001_00000067.pdf',
#  '27337281848_011_00001_00000068.pdf',
#  '27337281848_011_00001_00000071.pdf',
#  '28.12.21 - CUADRO ACLARATORIO.pdf',
#  '30716340437_001_00008_00000615 (1).pdf',
#  '30716340437_001_00008_00000615.pdf',
#  '33728184_00481560356_209.pdf',
#  '33728184_00481560356_215.pdf',
#  '3433c269-0ce2-43bb-ba5d-e7f0250dd7f1.png',
#  '34839009_00481560020_209.pdf',
#  '34839009_00481560020_215 (1).pdf',
#  '34839009_00481560020_215.pdf',
#  '45348299_00593220695_71.pdf',
#  '479DB831A98716E2F3F301DC393327BB_labels.pdf',
#  '7056.pdf',
#  '7650399082_Entrega.pdf',
#  '9664.pdf',
#  'Abastecedor - 2020.docx',
#  'Abastecimiento 2.1 (09.04).xlsm',
#  'Abastecimiento 2.1 (3).xlsm',
#  'Abastecimiento 2.1 07.05.xlsm',
#  'Abastecimiento 2.1 08.05.xlsm',
#  'Abastecimiento 2.1.xlsm',
#  'Abril - 2020 - CIF v.0.xlsx',
#  'ACRILICO-ean y dun.xlsx',
#  'AcrilTop-FEB20 1LT.pdf',
#  'AcrilTop-FEB20 4 LT.pdf',
#  'ACTA NUEVA DECRETO COVID-19.pdf',
#  'Acuerdo-20348390091-20200515.pdf',
#  'Adjectives+set+5+example+sentences.pdf',
#  'AFIP - Administraciï¿½n Federal.pdf',
#  'AFIP - Administración Federal de Ingresos Públicos renata.pdf',
#  'AFIP _ Formulario 184.pdf',
#  'AFIP_-_Administración_Federal_de_Ingresos_Públicos.pdf',
#  'Agua.xlsx',
#  'ajustes_señaletica_paclin.pdf',
#  'alquiler.pdf',
#  'ALTA DE ARTICULO.xlsx',
#  'ALTA OLIVERO.docx',
#  'Anaconda3-2020.11-Windows-x86_64.exe',
#  'AndreaniOnlineEmpresas.pdf',
#  'android-studio-2020.3.1.25-windows (1).exe',
#  'Archon-Code-39-Barcode-Font.zip',
#  'arquivo.pdf',
#  'art-pro.xlsx',
#  'ARTICULOS costo variable (1).xlsx',
#  'ARTICULOS costo variable.xlsx',
#  'AutorizaciÃ³n expresa para la grabaciÃ³n 3.pdf',
#  'AUTORIZACIONES RETIRO.docx',
#  'Autorización Natación.pdf',
#  'Avery_Zweckform_70x36_mm_(No._3475)-1D_Code (1).PDF',
#  'Avery_Zweckform_70x36_mm_(No._3475)-1D_Code.PDF',
#  'B15555.HTM',
#  'barcode.gif',
#  'Base de códigos para Estruc. Merc..xlsx',
#  'BASE PARA STOCK POR SUCURSALES 2021.xlsx',
#  'biblioteca_popular.csv',
#  'BLACK & DECKER LISTA MAREQ N° 241 JULIO 2020.pdf',
#  'black-python-wallpaper-2.jpg',
#  'BoletoME-4960819.pdf',
#  'Boleto_10038185.pdf',
#  'Boleto_5364838.pdf',
#  'Boleto_9306564.pdf',
#  'Boleto_9704104.pdf',
#  'Boleto_9926616.pdf',
#  'BONIFICACIONES ACTUALIZADAS FACU.pdf',
#  'Brochure Compilado - FY21.pdf',
#  'Bucking Pound Totals 2021 1st Half (1).ods',
#  'C1243584.pdf',
#  'Campaña del pañal- NI.pdf',
#  'CamScanner 01-28-2021 12.48.pdf',
#  'CamScanner 02-04-2021 15.51.pdf',
#  'CamScanner 02-18-2021 14.03.pdf',
#  'CamScanner 04-13-2021 08.55 (1).pdf',
#  'CamScanner 04-13-2021 08.55.pdf',
#  'CamScanner 05-16-2020 06.49.37_1.pdf',
#  'CamScanner 06-14-2021 14.27.pdf',
#  'CamScanner 06-30-2020 09.43.53.pdf',
#  'CamScanner 09-15-2021 08.37.pdf',
#  'CamScanner 09-18-2020 17.18.51.pdf',
#  'CamScanner 10-06-2021 12.52.pdf',
#  'CamScanner 12-22-2021 11.22.pdf',
#  'Canales+de+Autoayuda+en+Español.pdf',
#  'canalizador credifin.xlsx',
#  'Canalizador Localidades digital Ago.21.pdf',
#  'carga - bariloche.pdf',
#  'CartaTransporte Colorants.doc',
#  'CASA MATRIZ (PACLIN).pdf',
#  'caso cliente Santiago Centini - Suc Alem -29-10-2020.pptx',
#  'CATEGORIAS RESIDUOS PELIGROSOS Y.pdf',
#  'CBU Alpha SA (2).pdf',
#  'CBU ALPINA.pdf',
#  'cbu FEDERICO 34.839.009.jpeg',
#  'CBU PACLIN.pdf',
#  'Cerificado para circular CANALE.pdf',
#  'certif papa.pdf',
#  'CERTIFICADO PYTHON.jpg',
#  'CERTIFICADO PYTHON.pdf',
#  'CERTIFICADO UNICO DE SALUD.pdf',
#  'certificado-37475137.pdf',
#  'certificado-patente-aa447tj.pdf',
#  'certificado-patente-fht574.pdf',
#  'CertificadoDeFinalizacion_Fundamentos de la negociacion (1).pdf',
#  'Certificado_27337281848.pdf',
#  'cheat sheet pandas.pdf',
#  'Circ Adm 06-21 ARANCELES ACTUALIZADOS.pdf',
#  'Circular Adm 07-21 Aranceles 2022.pdf',
#  'Circular N° 6 Ordenamiento vehicular.pdf',
#  'CircularCuotaAfiliacion2022.pdf',
#  'Cliente.asciidoc',
#  'Cliente.md',
#  'Cliente.py',
#  'CLIENTES QUIMEX CAPITAL.xlsx',
#  'Clientes Sucursales (1).xlsx',
#  'Clientes Sucursales.xlsx',
#  'Cobertura ODO268 .pdf',
#  'Codigos-Postales-Argentina.xlsx',
#  'Coin Factura.pdf',
#  'Complete-Python-3-Bootcamp-master',
#  'Complete-Python-3-Bootcamp-master.zip',
#  'COMPRA RONDA DE NEGOCIO.xlsx',
#  'compremingreso.qrp.pdf',
#  'comprobante (1).pdf',
#  'comprobante (10).pdf',
#  'comprobante (2).pdf',
#  'comprobante (julio).pdf',
#  'comprobante alq junio.pdf',
#  'comprobante alq mayo.pdf',
#  'Comprobante de pago.pdf',
#  'Comprobante de transferencia (1).pdf',
#  'Comprobante de transferencia (2).pdf',
#  'Comprobante de transferencia.pdf',
#  'Comprobante Turno Jeronimo - DNI.pdf',
#  'Comprobante.pdf',
#  'ComprobanteCbuyAlias.pdf',
#  'comprobanteGeneracionCredin.pdf',
#  'comprobantePRESTAMOPRENDARIORCA0948.pdf',
#  'Comprobante_Pago febrero munic.pdf',
#  'Comprobante_Pago.pdf',
#  'Comunicaciòn 5-3.pdf',
#  'comunicado mercaderia.png',
#  'COMUNICADO OFICIAL (2).pdf',
#  'COMUNICADO VACACIONES 2022.pdf',
#  'config.ocg',
#  'CONIFERAL2-nuevo presupuesto.pdf',
#  'Consentimiento teleconsulta.docx',
#  'constanciadecuil-20348390091 (1).pdf',
#  'constanciadecuil-20348390091.pdf',
#  'constanciadecuil-27337281848.pdf',
#  'constancia_27337281848_2020-02-19.pdf',
#  'consumosMensuales.xls',
#  'CONTENEDOR-Modelo (1).pdf',
#  'CONTENEDOR-Modelo.pdf',
#  'Contrato de Servicios.docx',
#  'Copia de canalizador Tráfico.xls',
#  'Copia de Promociones Miura.xlsx',
#  'Copia de stock 07.05.xlsx',
#  'Copia de stock 08.05.2020.xlsx',
#  'Copia de stock 29.04.xlsx',
#  'COTIZACION INGEMAR.pdf',
#  'Credencial_27337281848 (202003).pdf',
#  'Credencial_27337281848 (202007).pdf',
#  'Credencial_27337281848 (202105).pdf',
#  'Credencial_27337281848 (202108).pdf',
#  'CRISTOBAL MUÑOZ - salta.pdf',
#  'CRISTOBAL MUÑOZ.pdf',
#  'Cronograma de licitación.xlsx',
#  'CUS 2021.pdf',
#  'Cv-Federico Morales Rampulla.pdf',
#  'd961dc58-3651-4719-951f-73e8a78d525d.png',
#  'DATA FISCAL PACLIN.pdf',
#  'data-analytics-partner.pdf',
#  'database.zip',
#  'DatosPowerBI.zip',
#  'Datosprocesadosdelos53sujetos.rar',
#  'DDJJ LICITUD DE FONDOS.PDF',
#  'Descargas',
#  'desktop.ini',
#  'detallada Armada 2020.xlsx',
#  'DEVOLUCION DE BARONE - nuevo analisis.xlsx',
#  'DEVOLUCION DE BARONE NVA CBA.xlsx',
#  'DEVOLUCION DE BARONE SUPER MAMI (1).xlsx',
#  'DEVOLUCION DE BARONE SUPER MAMI.xlsx',
#  'DEVOLUCION DE BARONE.xlsx',
#  'DEVOLUCION DE VARONE.xlsx',
#  'DEVOLUCION SILVIA FUENTES CONSOLIDADO.xlsx',
#  'DEWALT LISTA MAREQ N° 241 JULIO 2020 (1).pdf',
#  'DEWALT LISTA MAREQ N° 241 JULIO 2020.pdf',
#  'diluyentes .xlsx',
#  'dino entrega.jpeg',
#  'dino rechazo.jpeg',
#  'Discontinuos-origen.xlsx',
#  'DivXInstaller.exe',
#  'DJ EXTERNOS.pdf',
#  'DMToolkit_x64.zip',
#  'Doc 1.pdf',
#  'dslibro.pdf',
#  'EAN.xlsx',
#  'Ejemplo Procedimiento Comercial.docx',
#  'El Galgo - Mar2020.xlsx.xlsx',
#  'encabezado_encuesta.jpeg',
#  'Encuesta de Satisfacción  - Rev dirección.docx',
#  'Encuesta de Satisfacción - Logística.csv.zip',
#  'Encuesta de satisfacción de clientes (Respuestas) 2.xlsx',
#  'Enduido 1L Miura.jpg',
#  'Enero 2021.pdf',
#  'ENV ETIQUETAS NOVIEMBRE.xlsx',
#  'ePedido Mundo Helado 3300012708 (1).PDF',
#  'escalas_202101.pdf',
#  'esquema de planta.pdf',
#  'Estado de cuenta Pint Paclin 04-12-2020.xlsx',
#  'Estado de cuenta Pint Paclin 24-12-2020.xlsx',
#  'Estado_deuda_319858 (1).pdf',
#  'Estado_deuda_319858.pdf',
#  'ESTRUCTURA ART-ENVASADO (SOLO PARA HIPERVINCULO).xlsx',
#  'estructura mercadologica.xlsx',
#  'ESTRUCTURA PARA RICHARD.xlsx',
#  'ESTRUCTURA.xlsx',
#  'etiquetas preimpresas paclin (1).pdf',
#  'etiquetas preimpresas paclin 2021.pdf',
#  'etiquetas preimpresas paclin.pdf',
#  'ExcelRespuestaImagenes.xlsx',
#  'excelUltimosConsumosYPendientes.xls',
#  'exhibidor mastin.xlsx',
#  'F004CP Perfil de Puesto y Descripción de Analista de Abastecimiento.docx',
#  'FA 13082 COIN (1).pdf',
#  'FA 13082 COIN.pdf',
#  'FA 1725 1726 - IPAR.pdf',
#  'FA 1725 1726.pdf',
#  'FACA000200004001.pdf',
#  'FACA000300027099PINTURA.pdf',
#  'Fact 0004-00000036.pdf',
#  'FACT AUDAX - envio CAB.pdf',
#  'FACT12149DIAZYTAPIA.pdf',
#  'FACT16482DILMAS.pdf',
#  'FACTURA PACLIN1.pdf',
#  'FACTURA PACLIN2.pdf',
#  'FACTURA PINTURAS PACLIN.pdf',
#  'FACTURA PROFORMA 20-106.pdf',
#  'factura-debito-ECOGAS-nro-0400-12335665-000021361842-cen.pdf',
#  'factura-debito-ECOGAS-nro-0400-15332089-000021361842-cen.pdf',
#  'Faltantes.xlsx',
#  'FARA ENVASES - 1 litro lisos.pdf',
#  'feasibility+matrix.xlsx',
#  'Fede Morales – Operations Manager · Resume.io.pdf',
#  'fede morales.pdf',
#  'fede.qrp.pdf',
#  'Federico Morales - TeamInternational.pdf',
#  'Federico Morales Rampulla - cv.pdf',
#  'Federico Morales Rampulla- Flevo.pdf',
#  'Federico Morales Rampulla-alianTEC.pdf',
#  'Federico Morales Rampulla-English Speaking.pdf',
#  'Federico Morales Rampulla.pdf',
#  'FEFO.xlsx',
#  'Ferrimaq + CorreoArg.pdf',
#  'ficha de vacantes 2021.docx',
#  'FICHA TECNICA a completar.xlsx',
#  'Firebird-4.0.1.2692-0-x64.exe',
#  'firebird.exe',
#  'firebird_driver-1.4.1-py3-none-any.whl',
#  'FLUJO_DE_FONDOS-1.xlsx',
#  'FOR INCORPORACION DE RECIEN NACIDO edit.pdf',
#  'Forecasting+Resources+(ST+Academy).zip',
#  'Form dec Jur - 1.pdf',
#  'FORMULARIO DE PROTOCOLO DE CALIDAD.ods',
#  'FP 04 - Procedimiento de Desarrollo.docx',
#  'Fri Feb 12 14_09_08 GMT-03_00 2021_comprobante.pdf',
#  'getrotulo -sanluis1.pdf',
#  'getrotulo -sanluis2.pdf',
#  'getrotulo ferrimaq.pdf',
#  'getrotulo.pdf',
#  'Git-2.31.1-64-bit.exe',
#  'GRIDEST LISTA MAREQ N° 241 JULIO 2020.pdf',
#  'GS1_Non-Std_Heterogeneous.PDF',
#  'Habilitación Municipal  D.G.H.U  Año   2020 - 2021.pdf',
#  'Historial_Pago.pdf',
#  'Historico de Ordenes.xls',
#  'Hoja de cálculo sin título (1).xlsx',
#  'iberia marinsal.pdf',
#  'IMG-20201228-WA0013.jpeg',
#  'IMPRESION MANIFIESTO 2.pdf',
#  'IMPRESION MANIFIESTO.pdf',
#  'Influencers - Paclín (1).xlsx',
#  'Influencers - Paclín.xlsx',
#  'Informe de Multas - AD803UX.pdf',
#  'Informe No conformidad Entonadores Miura.pdf',
#  'Informe psicotecnico Juan Pablo Barragan.pdf.pdf',
#  'informe-deuda.pdf',
#  'InformeDominio (1).pdf',
#  'InformeDominio.pdf',
#  'InformePaclín.pdf',
#  'Informe_Nro_000300015074 dino.pdf',
#  'INSTITUCIONAL2020.pdf.pdf',
#  'INVENTARIO 2020 V2.xlsx',
#  'Inventario 2021_2022 (1).xlsx',
#  'Inventario 2021_2022 (2).xlsx',
#  'Inventario 2021_2022 (3).xlsx',
#  'Inventario 2021_2022.xlsx',
#  'INVENTARIO ALEM 27-11-2020.xlsx',
#  'INVENTARIO ARMADA 18-11-2020.xlsx',
#  'INVENTARIO FABRICA 14-12-2020.xlsx',
#  'INVENTARIO JBJ 10-12-2020.xlsx',
#  'INVENTARIO SABATTINI 01-12-2020.xlsx',
#  'Invoice 158.pdf',
#  'Invoice 169.pdf',
#  'ITPS Brochure Institucional.pdf',
#  'Juan Pablo Barragan (Auditor).doc',
#  'La Sabiduría del Eneagrama (Grupo 6)-1.pdf',
#  'Labeljoy6Setup.exe',
#  'Las-3-estrategias-de-Marketing-Digital-que-no-pueden-faltar-a-tu-empresa-este-ano.pdf',
#  'LEADERBOARD 2021 - SABADO 15-05 LA MELINCA.pdf',
#  'LearnToCodeRPG-1.0-pc.zip',
#  'LIBERTAD 1.pdf',
#  'LIBERTAD 2.pdf',
#  'LibreOffice_7.2.2_Win_x64.msi',
#  'LIQUIDACION MIURA SUCUS - 28-05-20 -.xlsx',
#  'LIQUIDACION MIURA SUCUS - stock pasado por Fefo 26-05-20 -.xlsx',
#  'liquidacion_CB_617-426683000.pdf',
#  'Lisos - A.Box - Mayo 2020.pdf',
#  'LISTA 1.xlsx',
#  'LISTA DE PRECIOS ENERO 2021.pdf',
#  'LISTA DEPOSITO.pdf',
#  'lista ean.xlsx',
#  'LISTA PARA KARI SUPER-venta hipermercado.xlsx',
#  'lista-de-precios-PY-MiCorreo.pdf',
#  'lista-de-precios-PY-MiCorreo.xlsx',
#  'Listado Celulares The Tech Room ARG - CELULARES (2).pdf',
#  'Listado de clientes 13-02-2020 (1).xlsx',
#  'Listado Productos EM - Inventario - 04-11-20 -.xlsx',
#  'LJM203-M206_UWWL_UWWL_Basicx64_44.5.2694.exe',
#  'Localidades atendidas Set 2021.xlsx',
#  'LP 132 Accesorios.pdf',
#  'LP 139 Mostrador Rodriguez.xlsx',
#  'LP Nº 143- PACLIN NV - Vig -01-10-21 -.xlsx',
#  'MAC Presupuesto 27-11-19.jpeg',
#  'MASTER CODE SUPER NUEVO (4).xlsx',
#  'MASTER CODE SUPER NUEVO.xlsx',
#  'MESA DULCE 1.xlsx',
#  'Microsoft_Remote_Desktop-8.1.82.445-1.apk',
#  'miura pendiente marinsalda 2 (1).pdf',
#  'miura pendiente marinsalda 2.pdf',
#  'miura pendiente marinsalda.pdf',
#  'MODELO DE LISTA DE INVITADOS MODO RESTO (1).xlsx',
#  'MODELO DE LISTA DE INVITADOS MODO RESTO.xlsx',
#  'ModelosElAtardecer.pptx',
#  'MORALES.pdf',
#  'More Than 1.98 Billion Shots Given_ Covid-19 Vaccine Tracker.pdf',
#  'movimientosHistoricos (2).xls',
#  'MovimientosHistoricos (2)_archivos',
#  'MovimientosHistoricos (3).xls',
#  'MovimientosHistoricos.xls',
#  'NC2000DILMASSRL.pdf',
#  'NC3404LOGAREZ.pdf',
#  'NC427DOMINGUEZ.pdf',
#  'NC_A_0004-00000609_--_0469991A-A0E2-466B-A8FA-899F2FA2F4C2.pdf',
#  'NEGATIVOS.xlsx',
#  'Nota de Venta x Mail LP 143 23-06-2021.xlsm',
#  'Nota para clientes transportes (1).docx',
#  'Nota para clientes transportes.docx',
#  'notas de pedido fefo (1).xlsx',
#  'notas de pedido fefo.suc.xlsx',
#  'notas de pedido fefo.xlsx',
#  'notasventa 05-11.qrp_4.pdf',
#  'NUEVO LISTADO ADOLFO CARGAR.xlsx',
#  'NumPy',
#  'OC GLP.pdf',
#  'OC INDUR28-04-20.pdf',
#  'OC SEPC CHEC 05-05-20.pdf',
#  'OC SMART 0-05-20.pdf',
#  'OC Sorvicor.pdf',
#  'OC Tubojet.pdf',
#  'OC-01-09-21.pdf',
#  'Omnichannel  inConcert Portfolio.pdf',
#  'opcionesCancelacion.xls',
#  'openpyxl-3.0.7-py2.py3-none-any.whl',
#  'OPN200x Setup.exe',
#  'Oportunidades para PyMEs (Gobierno Córdoba) Presentación.pdf',
#  'ORDEN DE COMPRA A A TODO TARRO 17-06-20.pdf',
#  'ORDEN DE COMPRA A AMICHEM 10-03-20.pdf',
#  'ORDEN DE COMPRA A BASF 18-03-20.pdf',
#  'ORDEN DE COMPRA A CLARIANT 18-03-20.pdf',
#  'ORDEN DE COMPRA A NAO 08-01-21.pdf',
#  'ORDEN DE COMPRA A QUIMVAR 14-01-21.pdf',
#  'ORDEN DE COMPRA A SMART 09-03-20.pdf',
#  'ORDEN DE COMPRA A SMART 29-07-20.pdf',
#  'ORDEN DE COMPRA A SPEC 18-03-20.pdf',
#  'ORDEN DE COMPRA A VARKEM 20-07-20.pdf',
#  'ORDEN DE COMPRA A VARKEM 29-07-20.pdf',
#  'orden de compra polidur.pdf',
#  'ordencompraZEOCAR.qrp.pdf',
#  'ordenpp2573actual.qrp (1).pdf',
#  'ORIGINAL (1).pdf',
#  'P.POD - Proveedores (Maximilino Diaz).pdf',
#  'PACLIN (1).pdf',
#  'paclin (2).pdf',
#  'PACLIN - PINT_AR.pdf',
#  'PACLIN 19-01-2021.docx',
#  'PACLIN CASA CENTRAL.pdf',
#  'PACLIN CASA MATRIZ.pdf',
#  'PACLIN CONTENEDOR contactcenter ESQUEMA DE ELECTRICIDAD.pdf',
#  'PACLIN CONTENEDOR LOGISTICA ESQUEMA DE ELECTRICIDAD.pdf',
#  'PACLIN FACTURA.pdf',
#  'Paclin Nota de Pedido.pdf',
#  'paclin pendiente marinsalda.pdf',
#  'PACLIN-COT1011-8521-CPU I3+MONITOR.pdf',
#  'paclin.pdf',
#  'PACLIN1 (1).pdf',
#  'PACLIN1 (2).pdf',
#  'PACLIN1 (3).pdf',
#  'PACLIN1 26_5 (1).pdf',
#  'PACLIN1 26_5.pdf',
#  'PACLIN1.pdf',
#  'PACLIN2 (1).pdf',
#  'PACLIN2 (2).pdf',
#  'PACLIN2 (3).pdf',
#  'PACLIN2 26_5 (1).pdf',
#  'PACLIN2 26_5.pdf',
#  'PACLIN2.pdf',
#  'PACLIN3 (1).pdf',
#  'PACLIN3.pdf',
#  'PACLIN4.pdf',
#  'PACLIN5.pdf',
#  'PACLIN6.pdf',
#  'PACLIN7.pdf',
#  'PACLIN8 (1).pdf',
#  'PACLIN8.pdf',
#  'PACLIN9.pdf',
#  'Paclin_logo_2020.pdf',
#  'Paclin_logo_2020.pdf.pdf',
#  'PaclínEnNúmeros_FINAL.mp4',
#  'PayPal_ Detalles de la transacción KYTE.pdf',
#  'PCE0000324917SCRIPT AR41 BUE0191C.pdf',
#  'pdf_201121183909.pdf',
#  'pdf_210121215433.pdf',
#  'PEDIDO (1).xlsx',
#  'Pedido 16 GABY - DISANCO - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'Pedido 16 GABY - F LOGAREZ - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'Pedido 16 GABY - LA PINTURERIA SH - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'Pedido 16 GABY - LIENDO - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'Pedido 19 TRIS - DILMAS - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'Pedido 20 HERNAN - LUIS ARGAÑARAZ - Operacion noviembre 2021 - 10-11-21 -.xlsx',
#  'pedido energizer SUCURSALES (1).xlsx',
#  'pedido energizer SUCURSALES.xlsx',
#  'PEDIDO INICIAL LIBERTAD 22-07.xlsx',
#  'pedido LUIS ARGAÑARAZ accesorios.xlsx',
#  'pedido LUIS ARGAÑARAZ hogar y obra (1).xlsx',
#  'pedido LUIS ARGAÑARAZ hogar y obra.xlsx',
#  'Pedido Paclin 27-05-2020-2 (1).xlsx',
#  'Pedido Paclin 27-05-2020-2.xlsx',
#  'PEDIDO.xlsx',
#  'PEDIDOS2021.docx',
#  'pendientes 1.xlsx',
#  'pendientes.xlsx',
#  'Perfil de Puesto y Descripción de Asistente Gerencia.pdf',
#  'permiso 3.5.pdf',
#  'PERMISO BASF.doc',
#  'PERMISO FAEN - COLONIA SRL.doc',
#  'permiso INDUR.doc',
#  'Permiso JMG.doc',
#  'PERMISO VERDOL - COLONIA SRL.doc',
#  'Permiso ZEOCAR.doc',
#  'PINTURA (1).pdf',
#  'PINTURA.pdf',
#  'PINTURAS PACLIN (PLANO SOPORTE P-VIGA TUBULAR)(19-05-20).pdf',
#  'Pinturas Paclin - Cotizacion.pdf',
#  'Pinturas Paclin brillantes y medidas especiales (08-05-2020).pdf',
#  'Pinturas Paclin camion completo con descuento.pdf',
#  'Pinturas Paclin camion completo.pdf',
#  'Pinturas Paclin Factura 4 pallets.pdf',
#  'Pinturas Paclin Factura entrega en Transporte IMAR.pdf',
#  'Pinturas Paclin Factura Marzo por 12 pallets, camion completo y retiro.pdf',
#  'Pinturas Paclin Factura Primera Quincena Febrero.pdf',
#  'Pinturas Paclin litografiados todas las medidas (22-06-2020).pdf',
#  'Pinturas Paclin Marzo.xlsx',
#  'Pinturas Paclin medidas envases rectificación (06-02-2020).pdf.pdf',
#  'Pinturas Paclin Nota de Credito por HD Envasamientos.pdf',
#  'Pinturas Paclin Nota de Crédito por Factura 645.pdf',
#  'PINTURAS PACLIN S.A (03-09-20)(Pr N° 5577) (1).pdf',
#  'PINTURAS PACLIN S.A (03-09-20)(Pr N° 5577) (2).pdf',
#  'PINTURAS PACLIN S.A (03-09-20)(Pr N° 5577).pdf',
#  'PINTURAS PACLIN S.A (04-09-20)(Pr N° 5580) PENETRABLE.pdf',
#  'PINTURAS PACLIN S.A (07-06-21)(Pr N° 7124).pdf',
#  'PINTURAS PACLIN S.A (18-05-20)(Pr N° 4995 ).pdf',
#  'PINTURAS PACLIN S.A (20-04-21)(Pr N° 6804).pdf',
#  'PINTURAS PACLIN S.A (25-07-20)(Pr N° 5346).pdf',
#  'PINTURAS PACLIN S.A (26-07-21)(Pr N° 7469).doc',
#  'PINTURAS PACLIN S.A (26-07-21)(Pr N° 7469).pdf',
#  'PINTURAS PACLIN S.A (31-07-20)(Pr N° 5346) modificada.pdf',
#  'PINTURAS PACLIN S.A (DETALLE DE ARMDO) - copia (1).pdf',
#  'PINTURAS PACLIN S.A (DETALLE DE ARMDO) - copia.pdf',
#  'PINTURAS PACLIN S.A (DETALLE DE ARMDO).docx',
#  'Planificación Estrategica 2021 1.xlsx',
#  'Planilla Gastos Nicolas Arguello - SEPTIEBRE 2020 -.xlsx',
#  'PLANO MANSUETO RENA Y FEDE APROXIMADO.jpg',
#  'planta 04.pdf',
#  'Porton 1.jpeg',
#  'porton 2.jpeg',
#  'Postman Agent-win64-0.3.5-Setup.exe',
#  'PRECIOS EXCEL COMPLETA.xlsx',
#  'PRECIOS TEORICOS Vs Propuestas - 17-09- 20 -.xlsx',
#  'Presentacion NEXSAT 2021.pdf',
#  'Presentación CBA.pdf',
#  'Presentación CVC 16-Nov-2021.pdf',
#  'presupuesto logistica (1).pdf',
#  'presupuesto logistica.pdf',
#  'PRESUPUESTO PACLIN.pdf',
#  'PRESUP__0000-00005756___22-5-2020.pdf',
#  'PREVIEW_TriEffect-Paclín-ABR20 (1).pdf',
#  'PREVIEW_TriEffect-Paclín-ABR20.pdf',
#  'process+prioritization.xlsm',
#  'PRODUCTOS PARA RETIRAR PROMOS ENERO20.xlsx',
#  'productos sin ean.xlsx',
#  'Profile (1).pdf',
#  'Profile (2).pdf',
#  'PROFORMA PINTURAS PACLIN SA 210628PP.pdf',
#  'prueba.txt',
#  'PWEB Buchhammer 2DIC.pdf',
#  'PWEB INDS. MAR.pdf',
#  'pycharm-professional-2021.3.exe',
#  'RECLAMO SALTA.jpeg',
#  'Reglas-2019-Versión-17-de-octubre-.pdf',
#  'remito 107816.pdf',
#  'REMITO15088NUÑEZ.pdf',
#  'REMITO332ARMADA.pdf',
#  'REMITO333RUTA20.pdf',
#  'REMITO334ALEM.pdf',
#  'Renders.pdf',
#  'repinventarios.qrp.xlsx',
#  'Req. envases y etiquetas.xlsx',
#  'reque. env.xlsx',
#  'requerimiento.xlsx',
#  'requirements.txt',
#  'Resultados resumidos final.pdf',
#  'RESULTADOS SORTEO 30_12_2021.pdf',
#  'RESULTADOS_BUSQUEDA.zip',
#  'Resumen de entrevista Barragan.pdf',
#  'resumenMensual (1).pdf',
#  'resumenMensual.pdf',
#  'Resumen_0980489167.pdf',
#  'resumen_cuenta_15_5_2020.pdf',
#  'resumen_cuenta_18_4_2021.pdf',
#  'ROTULO PINTURAS PACLIN 2.docx',
#  'RPA -demo.mp4',
#  'RTO 8650 COIN (1).pdf',
#  'RTO 8650 COIN.pdf',
#  'Rubio.pdf',
#  'Sabattini pre inventario.xlsx',
#  'Sabattini.xlsx',
#  'sala niño jesus nota imagen.docx',
#  'saldo de luis argañaraz cargado 291020.xlsx',
#  'Sector Bancario_BMAvsGGAL.pdf',
#  'SELECCION DE FOTOS.xltx',
#  'SELECCION DE FOTOS2.xlsx',
#  'Semaforo operativo.xlsx',
#  'servicio morales.pdf',
#  'SETALUX 1152 SS 60 (1).pdf',
#  'SETALUX 1152 SS 60.pdf',
#  'SETALUX 1152 SS60 (1).pdf',
#  'SETALUX 1152 SS60.pdf',
#  'setup.py',
#  'Showroom Juan fernandez .pdf',
#  'sinir101_1_8_50100032988_132917.pdf',
#  'Skype-8.58.0.93.exe',
#  'Solicitud Empleado - correo personal.docx',
#  'Solicitud202004151206242601.pdf',
#  'Solution.pdf',
#  'Solvente.xlsx',
#  'status inventario+ (2) - nahir.xlsx',
#  'STOCK 01-03 v15.xlsx',
#  'STOCK 08-01 v14.xlsx',
#  'STOCK 25-02 v15.xlsx',
#  'stock 3.04.xlsx',
#  'stock 9.04.xlsx',
#  'stock_fin_de_a_o_2021-11-12_11.34am.png',
#  'Sublime Text Build 3211 x64 Setup.exe',
#  'TARIFA DE VIAJES (1).xlsx',
#  'TARIFA DE VIAJES.xlsx',
#  'tarifa PACLIN.doc',
#  'Thu Mar 04 09_15_44 GMT-03_00 2021_comprobante.pdf',
#  'thumbnail_05VISADP.jpg',
#  'TIMING MANSUETO RENATA Y FEDERICO 22-8-21 (1).xlsx',
#  'TodosLosPedidos-Desde01082021-Hasta31102021.csv',
#  'TP-LINK_100Mbps_Ethernet_USB_Adapter.sfx.exe',
#  'TransferenciaInmediata-36125886_21-02-2020.pdf',
#  'Transferencia_otras_cuentas.pdf',
#  'transferncia IMAZ.jpeg',
#  'TriEffect-Paclín-ABR20.pdf',
#  'TriEffect-Paclín-ABR20_CONTROL.pdf',
#  'Trimmer Pound Totals 2021 New (3).ods',
#  'TSC_2021.2.exe',
#  'ultimoResumen.xls',
#  'UNZIP_FOR_NOTEBOOKS_FINAL (1).zip',
#  'USB Drivers Installer.zip',
#  'VID-20201225-WA0020.mp4',
#  'Video+08+-+Proceso+de+establecimiento+de+miedos+PDF.pdf',
#  'virtual-classes.pdf',
#  'Walking-Wounded-1.zip',
#  'WhatsApp Image 2020-03-05 at 11.20.33.jpeg',
#  'WhatsApp Image 2020-05-06 at 15.58.05.jpeg',
#  'WhatsApp Image 2020-05-18 at 16.50.37.jpeg',
#  'WhatsApp Image 2020-05-20 at 08.40.47.jpeg',
#  'WhatsApp Image 2020-06-04 at 09.49.22.jpeg',
#  'WhatsApp Image 2020-07-24 at 14.23.49.jpeg',
#  'WhatsApp Image 2020-07-28 at 10.06.56.jpeg',
#  'WhatsApp Image 2020-10-21 at 12.27.30.jpeg',
#  'WhatsApp Image 2020-10-28 at 14.03.31.jpeg',
#  'WhatsApp Image 2020-11-02 at 13.44.22.jpeg',
#  'WhatsApp Image 2020-11-26 at 16.31.29.jpeg',
#  'WhatsApp Image 2020-12-23 at 09.49.36 (1).jpeg',
#  'WhatsApp Image 2020-12-23 at 09.49.36.jpeg',
#  'WhatsApp Image 2021-02-03 at 15.59.30.jpeg',
#  'WhatsApp Image 2021-02-12 at 13.41.46.jpeg',
#  'WhatsApp Image 2021-02-12 at 13.46.58.jpeg',
#  'WhatsApp Image 2021-02-12 at 16.42.49.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.10.10.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.10.29.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.10.41.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.11.06.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.11.27.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.11.42.jpeg',
#  'WhatsApp Image 2021-02-19 at 16.12.53.jpeg',
#  'WhatsApp Image 2021-03-02 at 11.05.51.jpeg',
#  'WhatsApp Image 2021-03-05 at 10.16.52.jpeg',
#  'WhatsApp Image 2021-03-08 at 09.11.58 (1).jpeg',
#  'WhatsApp Image 2021-03-08 at 09.11.58 (2).jpeg',
#  'WhatsApp Image 2021-03-08 at 09.11.58.jpeg',
#  'WhatsApp Image 2021-04-11 at 21.39.47.jpeg',
#  'WhatsApp Image 2021-04-13 at 15.07.55.jpeg',
#  'WhatsApp Image 2021-05-06 at 14.36.32.jpeg',
#  'WhatsApp Image 2021-05-12 at 10.10.28.jpeg',
#  'WhatsApp Image 2021-05-13 at 09.55.39.jpeg',
#  'WhatsApp Image 2021-11-01 at 09.41.27.jpeg',
#  'WhatsApp Image 2021-11-04 at 10.27.32.jpeg',
#  'WhatsApp Image 2021-11-25 at 09.27.36.jpeg',
#  'WhatsApp Image 2021-11-25 at 11.00.26.jpeg',
#  'WhatsApp Image 2021-12-22 at 16.32.19.jpeg',
#  'WhatsApp Image 2022-01-04 at 09.03.31.jpeg',
#  'WhatsApp Image 2022-01-12 at 11.55.40.jpeg',
#  'WhatsApp Image 2022-01-12 at 12.55.03.jpeg',
#  'WhatsApp Image 2022-01-17 at 08.44.45.jpeg',
#  'WhatsApp Image 2022-01-17 at 10.17.34.jpeg',
#  'WhatsApp Image 2022-01-17 at 11.29.21 (1).jpeg',
#  'WhatsApp Image 2022-01-17 at 11.29.21.jpeg',
#  'WhatsApp Image 2022-01-19 at 22.11.36.jpeg',
#  'WhatsApp Unknown 2021-12-02 at 14.09.50.zip',
#  'WhatsApp Unknown 2022-01-24 at 11.12.09.zip',
#  'xampp-windows-x64-8.1.1-2-VS16-installer.exe',
#  'zebradesignerxml-v250-9427.exe',
#  '_var_www_html_notificar_factura_50643400',
#  '~$Influencers - Paclín (1).xlsx']

# %%
shutil.move("D:\\Downloads\\biblioteca_popular.csv","C:\\Users\\Usuario\\Phyton Stuff\\alkemy")

# Movemos el archivo descargado
# Out:
# 'C:\\Users\\Usuario\\Phyton Stuff\\alkemy\\biblioteca_popular.csv'

# %% [markdown]
# Leemos y comenzamos a manipular el archivo para estandarizar

# %%
df = pd.read_csv('biblioteca_popular.csv',delimiter=',')

# %%
df.columns
# Out:
# Index(['Cod_Loc', 'IdProvincia', 'IdDepartamento', 'Observacion', 'Categoría',
#        'Subcategoria', 'Provincia', 'Departamento', 'Localidad', 'Nombre',
#        'Domicilio', 'Piso', 'CP', 'Cod_tel', 'Teléfono', 'Mail', 'Web',
#        'Información adicional', 'Latitud', 'Longitud', 'TipoLatitudLongitud',
#        'Fuente', 'Tipo_gestion', 'año_inicio', 'Año_actualizacion'],
#       dtype='object')

# %% [markdown]
# o cod_localidad \
# o id_provincia \
# o id_departamento \
# o categoría \
# o provincia \
# o localidad \
# o nombre \
# o domicilio \
# o código postal \
# o número de teléfono \
# o mail \
# o web

# %%
df.rename(columns={'Cod_Loc':'cod_localidad','IdProvincia':'id_provincia','IdDepartamento':'id_departamento',
                  'Categoría':'categoria','Provincia':'provincia','Localidad':'localidad','Nombre':'nombre',
                  'Domicilio':'domicilio','CP':'codigo postal','Mail':'mail','Web':'web'}, inplace=True)


# DROPEAR: Observacion, subcategoria, Departamento, Piso, Informacion adiclional, latitud, longitud, tipolatitulongitud,fuente,
# tipo gestion, pantallas, butacas, espacio incaa, año actualizacion

# numero de telefono = cod_tel + telefono

# se quitan las tildes de las letras para evitar caracteres especiales en el codigo, aceptando el error de ortografia

# %%
df.columns
# Out:
# Index(['cod_localidad', 'id_provincia', 'id_departamento', 'Observacion',
#        'categoria', 'Subcategoria', 'provincia', 'Departamento', 'localidad',
#        'nombre', 'domicilio', 'Piso', 'codigo postal', 'Cod_tel', 'Teléfono',
#        'mail', 'web', 'Información adicional', 'Latitud', 'Longitud',
#        'TipoLatitudLongitud', 'Fuente', 'Tipo_gestion', 'año_inicio',
#        'Año_actualizacion'],
#       dtype='object')

# %%
df['numero de telefono'] = df['Cod_tel']+df['Teléfono']

# %%
df['numero de telefono']
# Out:
# 0           s/ds/d
# 1       1145010078
# 2       1149880766
# 3       1145729107
# 4       1147753325
#            ...
# 2012        s/ds/d
# 2013    s/d4331521
# 2014        s/ds/d
# 2015    2934497263
# 2016        s/ds/d
# Name: numero de telefono, Length: 2017, dtype: object

# %%
estandar_biblioteca = df[['cod_localidad','id_provincia','id_departamento','categoria','provincia','localidad','nombre','domicilio',
                   'codigo postal','numero de telefono','mail','web']]

# %%
estandar_biblioteca.head()
# Out:
#    cod_localidad  id_provincia  id_departamento              categoria  \
# 0       70049060            70            70049  Bibliotecas Populares
# 1        2000010             2             2000  Bibliotecas Populares
# 2        2000010             2             2000  Bibliotecas Populares
# 3        2000010             2             2000  Bibliotecas Populares
# 4        2000010             2             2000  Bibliotecas Populares
#
#                          provincia               localidad  \
# 0                         San Juan                   Rodeo
# 1  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 2  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 3  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires  Ciudad de Buenos Aires
#
#                                         nombre             domicilio  \
# 0         Biblioteca Popular Juan P. Garramuno         Santo Domingo
# 1  Biblioteca Popular Helena Larroque de Roffo          Simbrón 3058
# 2             Biblioteca Popular 12 de Octubre  Calle Arengreen 1187
# 3    Biblioteca Popular Villa Pueyrredón Norte         Cockrane 2334
# 4                   Biblioteca Popular Alberdi           Acevedo 666
#
#   codigo postal numero de telefono                                   mail  web
# 0          5465             s/ds/d                                    s/d  NaN
# 1      C1417EUD         1145010078           asociacionroffo@yahoo.com.ar  NaN
# 2      C1405CYM         1149880766         popular12deoctubre@hotmail.com  NaN
# 3      C1419FMD         1145729107       bibliotecapueyrredon@hotmail.com  NaN
# 4      C1414DJN         1147753325  bibliotecapopularalberdi@yahoo.com.ar  NaN

# %%
name = ''
name = str(estandar_biblioteca['categoria'][0])

# %%
import datetime

date = datetime.date.today()
year = date.strftime("%Y")
month = date.strftime('%m')
year_month = date.strftime('%Y - %m')

# %%
year_month
# Out:
# '2022 - 01'

# %%
archive = name + '-' + year_month + '.csv'

# %%
archive
# Out:
# 'Bibliotecas Populares-2022 - 01.csv'

# %%
estandar_biblioteca.to_csv(archive,sep=';')
